# %%
# Import Libraries
import pickle
import json
import pandas as pd
import numpy as np

# %%
# Loading Data
# Loading list_num_cols
with open('list_num_cols.txt', 'r') as file_1:
    num_cols = json.load(file_1)

# Loading list_cat_cols_ohe
with open('list_cat_cols_ohe.txt', 'r') as file_2:
    cat_cols_ohe = json.load(file_2)

# Loading list_cat_cols_ord
with open('list_cat_cols_ord.txt', 'r') as file_3:
    cat_cols_ord = json.load(file_3)

# Loading contract_order_for_encoder
with open('contract_order_for_encoder.txt', 'r') as file_4:
    contract_order_for_encoder = json.load(file_4)

# Loading preprocessor
with open('preprocessor.pkl', 'rb') as file_5:
    preprocessor = pickle.load(file_5)

# Loading chi_selector
with open('chi_selector.pkl', 'rb') as file_6:
    chi_selector = pickle.load(file_6)

# Loading anova_selector
with open('anova_selector.pkl', 'rb') as file_7:
    anova_selector = pickle.load(file_7)

# Loading best_pipeline (model)
with open('model.pkl', 'rb') as file_8:
    best_pipeline = pickle.load(file_8)

# %%
# Membuat Data Baru

new_data = {
    'gender': "Female",
    'SeniorCitizen': "No",
    'Partner': "Yes",
    'Dependents': "Yes",
    'tenure': 10,
    'PhoneService': "No",
    'MultipleLines': "No",
    'InternetService': "Fiber optic",
    'OnlineSecurity': "Yes",
    'OnlineBackup': "No",
    'DeviceProtection': "No",
    'TechSupport': "No",
    'StreamingTV': "Yes",
    'StreamingMovies': "No",
    'Contract': "Month-to-month",
    'PaperlessBilling': "Yes",
    'PaymentMethod': "Electronic check",
    'MonthlyCharges': 80,
    'TotalCharges': 800,

}

new_data = pd.DataFrame([new_data])
new_data
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService MultipleLines  \
# 0  Female            No     Yes        Yes      10           No            No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0     Fiber optic            Yes           No               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes              No  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges  TotalCharges
# 0  Electronic check              80           800

# %%
# Mendefinisikan Data Inference
data_inf = new_data.copy()

# %%
# Memptrdiksi menggunakan Pipeline
predictions = best_pipeline.predict(new_data)
print("Hasil Prediksi:")
print('Prediksi 0 = "Non-Churn", Prediksi 1 = "Churn"')
print(f'Hasil Prediksi Aadalah : {predictions}')
# Out:
# Hasil Prediksi:
# Prediksi 0 = "Non-Churn", Prediksi 1 = "Churn"
# Hasil Prediksi Aadalah : [1]

# %%
# Menampilkan Hasil Prediksi Berdasarkan data baru
data_inf['Churn'] = predictions
data_inf.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService MultipleLines  \
# 0  Female            No     Yes        Yes      10           No            No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0     Fiber optic            Yes           No               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes              No  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 0  Electronic check              80           800      1
